# %% [markdown]
# # Data Collection
# ## Pull data from Yahoo Finance

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf

# %%
# Define ticker symbols and date range
tickers = [
    "AAPL",  # Apple
    "MSFT",  # Microsoft
    "NVDA",  # Nvidia
    "SAP",   # SAP
    "TSM"    # Taiwan Semi
]

# Set start date to January 1, 2015
start_date = '2015-01-01'

# Set end date to today's date
end_date = pd.Timestamp.today().strftime('%Y-%m-%d')

# Fetch historical data
data = {}

for ticker in tickers:
    # Download raw data
    df = yf.download(
        ticker,
        start=start_date,
        end=end_date,
        auto_adjust=False,
        progress=False  
    )

    # Add ticker column
    df['Ticker'] = ticker

    # Resery index to have Date as a column
    df.reset_index(inplace=True)

    # Save individial cleaned DataFrame
    data[ticker] = df

    print(f"Downloaded data for {ticker}")
    display(df.head(2))
# Out:
# Downloaded data for AAPL
# Price        Date  Adj Close    Close       High        Low     Open  \
# Ticker                  AAPL     AAPL       AAPL       AAPL     AAPL
# 0      2015-01-02  24.237551  27.3325  27.860001  26.837500  27.8475
# 1      2015-01-05  23.554745  26.5625  27.162500  26.352501  27.0725
#
# Price      Volume Ticker
# Ticker       AAPL
# 0       212818400   AAPL
# 1       257142000   AAPL
# Downloaded data for MSFT
# Price        Date  Adj Close      Close       High        Low       Open  \
# Ticker                  MSFT       MSFT       MSFT       MSFT       MSFT
# 0      2015-01-02  39.933060  46.759998  47.419998  46.540001  46.660000
# 1      2015-01-05  39.565838  46.330002  46.730000  46.250000  46.369999
#
# Price     Volume Ticker
# Ticker      MSFT
# 0       27913900   MSFT
# 1       39673900   MSFT
# Downloaded data for NVDA
# Price        Date Adj Close    Close     High      Low     Open     Volume  \
# Ticker                 NVDA     NVDA     NVDA     NVDA     NVDA       NVDA
# 0      2015-01-02  0.483038  0.50325  0.50700  0.49525  0.50325  113680000
# 1      2015-01-05  0.474880  0.49475  0.50475  0.49250  0.50325  197952000
#
# Price  Ticker
# Ticker
# 0        NVDA
# 1        NVDA
# Downloaded data for SAP
# Price        Date  Adj Close      Close       High        Low       Open  \
# Ticker                   SAP        SAP        SAP        SAP        SAP
# 0      2015-01-02  58.992451  70.040001  70.360001  69.639999  69.790001
# 1      2015-01-05  56.600422  67.199997  68.360001  67.059998  68.300003
#
# Price    Volume Ticker
# Ticker      SAP
# 0        683600    SAP
# 1       1678800    SAP
# Downloaded data for TSM
# Price        Date  Adj Close      Close       High        Low       Open  \
# Ticker                   TSM        TSM        TSM        TSM        TSM
# 0      2015-01-02  16.676708  22.280001  22.459999  22.000000  22.450001
# 1      2015-01-05  16.272514  21.740000  22.170000  21.709999  22.139999
#
# Price    Volume Ticker
# Ticker      TSM
# 0       6074100    TSM
# 1       9031800    TSM

# %%
# Combine all data into a single DataFrame
combined_data = pd.concat(data.values(), ignore_index=True)
print("Combined data shape:", combined_data.shape)
display(combined_data.head(2))

# Save combined data to CSV to Data folder
combined_data.to_csv('../Data/Stock_data.csv', index=False)
# Out:
# Combined data shape:
#  (13660, 32)
# Price        Date  Adj Close    Close       High        Low     Open  \
# Ticker                  AAPL     AAPL       AAPL       AAPL     AAPL
# 0      2015-01-02  24.237551  27.3325  27.860001  26.837500  27.8475
# 1      2015-01-05  23.554745  26.5625  27.162500  26.352501  27.0725
#
# Price        Volume Ticker Adj Close Close  ... High Low Open Volume  \
# Ticker         AAPL             MSFT  MSFT  ...  SAP SAP  SAP    SAP
# 0       212818400.0   AAPL       NaN   NaN  ...  NaN NaN  NaN    NaN
# 1       257142000.0   AAPL       NaN   NaN  ...  NaN NaN  NaN    NaN
#
# Price  Adj Close Close High Low Open Volume
# Ticker       TSM   TSM  TSM TSM  TSM    TSM
# 0            NaN   NaN  NaN NaN  NaN    NaN
# 1            NaN   NaN  NaN NaN  NaN    NaN
#
# [2 rows x 32 columns]

# %%
combined_data.head(2)
# Out:
# Price        Date  Adj Close    Close       High        Low     Open  \
# Ticker                  AAPL     AAPL       AAPL       AAPL     AAPL
# 0      2015-01-02  24.237551  27.3325  27.860001  26.837500  27.8475
# 1      2015-01-05  23.554745  26.5625  27.162500  26.352501  27.0725
#
# Price        Volume Ticker Adj Close Close  ... High Low Open Volume  \
# Ticker         AAPL             MSFT  MSFT  ...  SAP SAP  SAP    SAP
# 0       212818400.0   AAPL       NaN   NaN  ...  NaN NaN  NaN    NaN
# 1       257142000.0   AAPL       NaN   NaN  ...  NaN NaN  NaN    NaN
#
# Price  Adj Close Close High Low Open Volume
# Ticker       TSM   TSM  TSM TSM  TSM    TSM
# 0            NaN   NaN  NaN NaN  NaN    NaN
# 1            NaN   NaN  NaN NaN  NaN    NaN
#
# [2 rows x 32 columns]
